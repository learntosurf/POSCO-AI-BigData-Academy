# %%
import random
import os

def is_overlapping(new_box, existing_boxes):
    for box in existing_boxes:
        dist_x = abs(new_box['x'] - box['x'])
        dist_y = abs(new_box['y'] - box['y'])
        if dist_x < (new_box['width'] / 2 + box['width'] / 2 + 0.5) and dist_y < (new_box['depth'] / 2 + box['depth'] / 2 + 0.5):
            return True
    return False

def generate_wbt_files(base_file_path, num_files, output_directory):
    with open(base_file_path, 'r') as file:
        base_content = file.read()

    for i in range(num_files):
        new_content = base_content
        existing_boxes = []  # 이미 배치된 박스들의 정보를 저장할 리스트
        
        # 장애물 수는 1~3개 랜덤하게 선택
        for j in range(random.randint(1, 3)):
            while True:  # 겹치지 않을 때까지 반복
                x = random.uniform(-2.0, 2.0)  # 벽에서 1m 이상 떨어진 x 위치
                y = random.uniform(-3.0, 3.0)  # 벽에서 1m 이상 떨어진 y 위치
                z = 0.3  # 장애물의 z 위치 (항상 고정된 높이로 바닥에 붙음)
                
                width = random.uniform(0.5, 2)  # 장애물의 너비
                depth = random.uniform(0.5, 2)  # 장애물의 깊이
                height = 0.5  # 장애물의 높이 (고정)

                new_box = {'x': x, 'y': y, 'width': width, 'depth': depth}
                
                # 기존 박스들과 겹치지 않는지 확인
                if not is_overlapping(new_box, existing_boxes):
                    existing_boxes.append(new_box)
                    break  # 겹치지 않으면 반복 종료

            # 새로운 WoodenBox 블록 생성 (X, Y, Z 좌표와 크기 모두 올바른 순서로 설정)
            new_box_str = f'''
WoodenBox {{
  translation {x:.6f} {y:.6f} {z:.6f}
  size {width:.6f} {depth:.6f} {height:.6f}
}}'''
            
            # 박스를 new_content에 추가
            new_content += new_box_str

        # 출력 디렉토리가 없으면 생성
        os.makedirs(output_directory, exist_ok=True)
        
        # 새로운 월드 파일 작성
        with open(f'{output_directory}/output_world_{i+1}.wbt', 'w') as new_file:
            new_file.write(new_content)

# 예시 실행
generate_wbt_files('/home/piai/DDPM_STE_GSL/Webots_worlds/init.wbt', 200, '/home/piai/DDPM_STE_GSL/Webots_worlds/outputs4')

# %%
import os
import subprocess

def convert_wbt_to_stl(wbt_file, output_directory):
    # Webots 명령줄을 사용하여 .wbt 파일을 STL 파일로 변환
    output_file = os.path.join(output_directory, os.path.basename(wbt_file).replace('.wbt', '.stl'))
    export_command = f'webots --mode=convert --output={output_file} {wbt_file}'
    
    # Webots 변환 명령 실행
    result = subprocess.run(export_command, shell=True, capture_output=True, text=True)
    
    if result.returncode == 0:
        print(f'Successfully converted {wbt_file} to {output_file}')
    else:
        print(f'Error converting {wbt_file}: {result.stderr}')

def process_wbt_files(wbt_directory, output_directory):
    # 경로에 있는 모든 .wbt 파일을 순회하며 STL로 변환
    wbt_files = [f for f in os.listdir(wbt_directory) if f.endswith('.wbt')]
    
    for wbt_file in wbt_files:
        wbt_path = os.path.join(wbt_directory, wbt_file)
        
        # .wbt 파일을 STL로 변환
        convert_wbt_to_stl(wbt_path, output_directory)

# 예시 실행
wbt_directory = '/home/piai/DDPM_STE_GSL/Webots_worlds/outputs3'
output_directory = '/home/piai/DDPM_STE_GSL/Webots_worlds/outputs3_stl'

# STL 파일 저장할 디렉토리 생성
os.makedirs(output_directory, exist_ok=True)

# 변환 실행
process_wbt_files(wbt_directory, output_directory)
# Out:
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_176.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_164.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_151.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_154.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_17.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_120.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_57.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_116.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_99.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_200.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_166.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_38.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_55.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_193.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_134.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_162.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_70.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_121.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_159.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_136.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_150.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_51.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_145.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_163.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_195.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_73.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_144.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_124.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_123.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_161.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_122.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_105.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_64.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_4.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_153.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_94.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_58.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_47.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_168.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_97.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_42.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_30.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_155.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_72.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_8.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_74.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_167.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_101.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_107.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_81.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_194.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_197.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_15.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_126.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_16.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_147.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_54.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_35.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_132.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_95.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_48.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_88.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_177.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_66.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_60.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_28.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_198.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_40.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_196.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_76.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_84.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_45.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_130.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_125.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_104.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_23.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_22.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_178.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_103.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_56.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_71.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_69.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_68.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_65.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_117.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_128.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_59.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_110.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_185.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_52.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_135.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_190.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_189.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_199.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_170.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_79.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_25.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_127.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_152.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_171.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_115.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_160.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_10.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_62.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_86.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_7.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_111.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_13.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_102.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_3.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_139.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_146.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_53.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_112.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_192.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_133.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_100.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_36.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_49.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_12.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_174.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_158.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_137.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_29.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_141.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_67.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_11.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_14.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_63.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_5.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_50.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_149.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_191.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_1.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_89.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_37.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_46.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_39.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_26.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_41.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_165.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_172.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_140.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_19.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_78.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_2.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_32.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_114.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_169.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_91.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_61.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_44.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_9.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_34.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_113.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_6.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_173.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_183.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_20.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_31.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_175.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_85.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_27.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_83.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_143.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_148.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_181.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_80.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_33.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_138.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_96.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_129.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_156.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_187.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_109.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_18.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_75.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_108.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_77.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_188.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_93.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_90.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_98.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_142.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_106.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_186.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_179.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_82.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_21.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_180.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_43.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_182.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_184.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_87.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_119.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_92.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_131.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_24.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_118.wbt: /bin/sh: 1: webots: not found
#
# Error converting /home/piai/DDPM_STE_GSL/Webots_worlds/outputs3/output_world_157.wbt: /bin/sh: 1: webots: not found
